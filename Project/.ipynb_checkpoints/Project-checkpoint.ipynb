# %%
import csv

# %%
f = open('life.csv', 'rb')
reader = csv.reader(f)
Years =[]
Life_Expectancy = []
rownum = 0
for row in reader:
    if rownum == 0:
        Years.append(row[4:])
    if row[0] == 'Spain':
        a = row
        print a
        a = map(float , a[4:len(a)-3])
        #a = map(float , a[4:len(a)-3]) 
        Life_Expectancy.append(row[4:])
        print a
    
    rownum += 1
f.close()
# Out:
# ['Spain', 'ESP', 'Life expectancy at birth, total (years)', 'SP.DYN.LE00.IN', '69.4804878048781', '69.5190243902439', '69.6812195121951', '70.399756097561', '70.8092682926829', '71.0551219512195', '71.2529268292683', '71.5378048780488', '71.0575609756098', '72.0273170731707', '71.630243902439', '72.8180487804878', '72.6107317073171', '72.969756097561', '73.3187804878049', '73.6426829268293', '74.1319512195122', '74.2956097560976', '74.8187804878049', '75.3492682926829', '75.5285365853659', '76.1341463414634', '75.9090243902439', '76.2953658536586', '76.259512195122', '76.5104878048781', '76.7280487804878', '76.7470731707317', '76.8136585365854', '76.8375609756098', '76.9712195121951', '77.41', '77.5465853658537', '77.9014634146342', '77.9807317073171', '78.1204878048781', '78.6041463414634', '78.6658536585366', '78.7170731707317', '78.9658536585366', '79.3682926829268', '79.5682926829268', '79.619512195122', '79.8707317073171', '80.1707317073171', '80.8219512195122', '80.873170731707
# ...
